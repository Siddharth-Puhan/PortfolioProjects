# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv('movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# Some of the release years don't match the year specified in the "released" column.
#
# Using Regular Expression to extract the correct year from "released" column

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Define a regular expression pattern to match the year (4 digits)
pattern = r'(\d{4})'

# Extract the year and add it as a new column 'ReleaseYear'
df['release_year'] = df['released'].str.extract(pattern)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Missing Data
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Data Types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Filling missing rows in order to perform the conversion
df = df.fillna(0)

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# pd.set_option('display.max_rows', None)
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# Dropping any duplicates

df.nunique()
# Out:
# name            7512
# rating            13
# genre             19
# year              41
# released        3415
# score             73
# votes            937
# director        2949
# writer          4536
# star            2815
# country           60
# budget           414
# gross           7473
# company         2386
# runtime          139
# release_year      42
# dtype: int64

# %% [markdown]
# There are 7512 movie names with 0 missing values for a dataset containing 7668 rows.
#
# There is a possibility that some movie names might be repeated.
#
# Let's check that

# %%
duplicate_names = df[df.duplicated(subset='name', keep=False)]
duplicate_names
# Out:
#                    name rating      genre  year  \
# 5       Friday the 13th      R     Horror  1980
# 16                 Fame      R      Drama  1980
# 18              The Fog      R     Horror  1980
# 31           Prom Night      R     Horror  1980
# 46           The Island      R     Action  1980
# ...                 ...    ...        ...   ...
# 7526            The Kid      R  Biography  2019
# 7529       Child's Play      R      Drama  2019
# 7536              Shaft      R     Action  2019
# 7556  After the Wedding  PG-13      Drama  2019
# 7623        The Captain      0     Action  2019
#
#                                released  score     votes            director  \
# 5           May 9, 1980 (United States)    6.4  123000.0  Sean S. Cunningham
# 16         May 16, 1980 (United States)    6.6   21000.0         Alan Parker
# 18     February 8, 1980 (United States)    6.8   66000.0      John Carpenter
# ...

# %%
duplicate_rows = df[df.name == "Shaft"]
duplicate_rows
# Out:
#        name rating   genre  year                       released  score  \
# 3727  Shaft      R  Action  2000  June 16, 2000 (United States)    6.0
# 7536  Shaft      R  Action  2019  June 14, 2019 (United States)    6.4
#
#         votes        director          writer               star  \
# 3727  75000.0  John Singleton  Ernest Tidyman  Samuel L. Jackson
# 7536  48000.0       Tim Story  Ernest Tidyman  Samuel L. Jackson
#
#             country    budget      gross              company  runtime  \
# 3727        Germany  46000000  107626125   Paramount Pictures     99.0
# 7536  United States  35000000   21360215  Davis Entertainment    111.0
#
#      release_year
# 3727         2000
# 7536         2019

# %% [markdown]
# These movies have the same name but are released on different dates/years

# %% [markdown]
# ## Finding Correlation in the data

# %% [markdown]
# ### Numeric Data

# %%
# Scatterplot with Budget Vs Gross

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
plt.title("Budget VS Gross")
plt.xlabel("Budget")
plt.ylabel("Gross")
# Out:
# Text(0, 0.5, 'Gross')

# %%
numeric_df = df.select_dtypes(['float64', 'int64'])
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %% [markdown]
# There is a high correlation between budget and gross, votes and gross, votes and score

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
df = df.sort_values(by='gross', ascending=False)
df
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %% [markdown]
# ### Categorical Data

# %%
df_numerized = df.copy()

for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 1617  3712       7      5  1989      1278    4.5      274.0       117      83
# 1614  1745       7     10  1989        56    5.2     1300.0      1033    1744
# 1606  2691       7      8  1989       258    6.0     2900.0      2743     947
# 1601  3836       0      4  1989      1161    7.1     1500.0      1105    1697
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
#
# ...

# %%
correlation_matrix = df_numerized.corr()
correlation_matrix
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating       -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre         0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year          0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released     -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score         0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes         0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director      0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer        0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star          0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country      -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget        0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# ...

# %%
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#                                 ...
# release_year  budget          0.300236
#               gross           0.255130
#               company        -0.014144
#               runtime         0.120344
#               release_year    1.000000
# Length: 256, dtype: float64

# %%
sorted_corr_pairs = corr_pairs.sort_values()
high_corr = sorted_corr_pairs[sorted_corr_pairs > 0.5]
high_corr
# Out:
# gross         votes           0.632870
# votes         gross           0.632870
# budget        gross           0.750157
# gross         budget          0.750157
# release_year  year            0.996397
# year          release_year    0.996397
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# release_year  release_year    1.000000
# dtype: float64
